# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Stuff" data-toc-modified-id="Import-Stuff-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Stuff</a></span><ul class="toc-item"><li><span><a href="#Prep-Data-for-Comparison" data-toc-modified-id="Prep-Data-for-Comparison-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Prep Data for Comparison</a></span></li></ul></li><li><span><a href="#Compare-Results" data-toc-modified-id="Compare-Results-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Compare Results</a></span><ul class="toc-item"><li><span><a href="#Bandgap" data-toc-modified-id="Bandgap-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Bandgap</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Import Stuff

# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(font_scale=1.5)

# %%
valet_bs = [] #[pkl.load(open('../pickles/cp_bs_part_{}.pkl'.format(i),'rb')) for i in np.arange(46)]
for i in np.arange(46):
    pkl_file = open('../pickles/cp_bs_part_{}.pkl'.format(i),'rb')
    for j in pkl.load(pkl_file):
        valet_bs.append(j)
orig_bs = pkl.load(open('../bench_set/pickles/matproj_bench_set_clean.pkl','rb'))

# %% [markdown]
# ## Prep Data for Comparison

# %%
bs_index = [i['index'] for i in valet_bs]
mp_bs = orig_bs.copy()
mp_remove = [key for key in mp_bs.keys() if key not in bs_index]

for key in mp_remove:
    del mp_bs[key]


mp_df = pd.DataFrame.from_dict(mp_bs,orient='index')
mp_df.reset_index(inplace=True)

qv_df = pd.DataFrame(valet_bs)
qv_df = qv_df[qv_df.bandgap >= 0]
qv_df.columns = ['bandgap_qv', 'bandgap_direct_qv', 'eos_errors', 'eos_fits', 'index','system', 'volume_vs_energy']


combined_df = mp_df.merge(qv_df,on='index')

# %% [markdown]
# # Compare Results
#
# ## Bandgap

# %%
combined_df[combined_df.bandgap_qv != combined_df.bandgap_direct_qv]
# Out:
#        index                                  structure_initial  \
# 6    mp-1062  (Atom('Mg', [0.0, 0.0, 0.0], magmom=0.0, index...
# 38   mp-1267  (Atom('C', [4.807756935162, 4.1030349118539, 1...
# 47    mp-130  (Atom('P', [0.860924629, 0.59666435575, 1.5774...
# 71    mp-181  (Atom('K', [0.1859468686250001, 3.6266133337, ...
# 73     mp-19  (Atom('Te', [1.1681983617, 0.0, 1.976066646906...
# 75    mp-191  (Atom('Y', [1.7045, 1.7045, 1.7045], magmom=0....
# 80    mp-213  (Atom('Ca', [0.0, 0.0, 0.0], magmom=0.0, index...
# 84    mp-230  (Atom('O', [3.3436919999999994, 4.5854684, 1.1...
# 89    mp-284  (Atom('Al', [0.0, 0.0, 0.0], magmom=0.0, index...
# 91    mp-292  (Atom('V', [2.37125, 1.185625, 0.0], magmom=0....
# 98    mp-344  (Atom('B', [2.8660546882049998, 4.159765782116...
# 103   mp-377  (Atom('Rh', [1.666, 1.666, 1.666], magmom=0.0,...
# 112   mp-436  (Atom('Rh', [0.0, 0.0, 0.0], magmom=0.0, index...
# 129   mp-602  (Atom('Mo', [-1.7590999989991474e-08, 2.031233...
# 142   mp-757  (Atom('Li', [0.0, 0.0, 1.97], magmom=0.0, inde...
# 164   mp-909  (Atom('As', [0.4749378125184, 7.952175, 8.8793...
#
#                                        structure_final  \
# 6    (Atom('Mg', [0.0, 0.0, 0.0], magmom=-0.001, in...
# 38   (Atom('C', [4.825614430787267, 4.1176342005260...
# 47   (Atom('P', [0.9643226452975404, 0.668324416923...
# 71   (Atom('K', [0.1831725352608329, 3.667287432499...
# 73   (Atom('Te', [1.2136052016506065, 0.0, 1.986632...
# 75   (Atom('Y', [1.721962485, 1.721962485, 1.721962...
# 80   (Atom('Ca', [0.0, 0.0, 0.0], magmom=-0.0, inde...
# 84   (Atom('O', [3.2690232523896023, 4.687526612435...
# 89   (Atom('Al', [0.0, 0.0, 0.0], magmom=0.0, index...
# 91   (Atom('V', [2.36790054, 1.18395027, 0.0], magm...
# 98   (Atom('B', [2.9152678908003145, 4.171256078202...
# 103  (Atom('Rh', [1.6786534, 1.6786534, 1.6786534],...
# 112  (Atom('Rh', [0.0, 0.0, 0.0], magmom=0.0, index...
# 129  (Atom('Mo', [-1.7793553075406976e-08, 2.054622...
# 142  (Atom('Li', [0.0, 0.0, 1.95331374], magmom=0.0...
# 164  (Atom('As', [0.52070062903918, 8.8276144453248...
#
#                         potcar  bandgap  bandgap_qv  bandgap_direct_qv  \
# 6      {'Mg': '_pv', 'Ce': ''}   0.0000      0.0412             0.1579
# 38      {'C': '', 'Na': '_pv'}   3.3846      0.0153             0.0633
# 47                   {'P': ''}   0.0000      0.0744             0.1125
# 71    {'K': '_sv', 'Ga': '_d'}   0.2163      0.3350             0.3627
# 73                  {'Te': ''}   0.1856      0.6158             0.9143
# 75   {'Y': '_sv', 'Rh': '_pv'}   0.0000      0.6330             1.5293
# 80     {'Ca': '_sv', 'Pd': ''}   0.0000      0.7553             1.3197
# 84         {'O': '', 'Sb': ''}   1.8830      1.8690             1.8741
# 89        {'Al': '', 'Co': ''}   0.0000      0.0985             1.0042
# 91      {'V': '_pv', 'As': ''}   0.0000      0.0147             0.2136
# 98          {'B': '', 'N': ''}   3.5766      3.7568             3.8082
# 103  {'Rh': '_pv', 'Lu': '_3'}   0.0000      0.8776             1.7401
# 112  {'Rh': '_pv', 'Sm': '_3'}   0.0000      0.4356             1.3463
# 129    {'Mo': '_pv', 'Te': ''}   0.9657      0.7355             1.3130
# 142    {'Li': '_sv', 'As': ''}   0.6365      1.0392             1.8140
# 164       {'As': '', 'Se': ''}   1.4392      1.2643             1.4356
#
#                     eos_errors  \
# 6                         None
# 38              [antonschmidt]
# 47              [antonschmidt]
# 71   [murnaghan, antonschmidt]
# 73              [antonschmidt]
# 75                        None
# 80                        None
# 84                        None
# 89                        None
# 91                        None
# 98                        None
# 103                       None
# 112                       None
# 129  [murnaghan, antonschmidt]
# 142                       None
# 164                       None
#
#                                               eos_fits  \
# 6    {'birch': {'buld_modulus': 0.26180158147485993...
# 38   {'murnaghan': {'buld_modulus': 0.2615132900133...
# 47   {'birchmurnaghan': {'volume': 32.4897045542929...
# 71   {'taylor': {'volume': 284.51893033926905, 'ene...
# 73   {'taylor': {'volume': 104.35353819899511, 'ene...
# 75   {'taylor': {'volume': 40.78461515900883, 'ener...
# 80   {'p3': {'buld_modulus': 0.3676785526179451, 'v...
# 84   {'birchmurnaghan': {'energy': -145.25456667561...
# 89   {'taylor': {'energy': -12.0744405915445, 'volu...
# 91   {'birch': {'buld_modulus': 1.1721890986909524,...
# 98   {'sjeos': {'energy': -69.36854257165598, 'volu...
# 103  {'sjeos': {'buld_modulus': 0.7794008375475033,...
# 112  {'taylor': {'energy': -13.548988989369933, 'vo...
# 129  {'sjeos': {'energy': -35.86068381395944, 'volu...
# 142  {'sjeos': {'buld_modulus': 0.22105569030085628...
# 164  {'birch': {'buld_modulus': 0.09669844667855787...
#
#                                                 system  \
# 6    (Atom('Mg', [0.0, 0.0, 0.0], magmom=0.0, index...
# 38   (Atom('C', [2.582059349153493, 3.9097260666669...
# 47   (Atom('P', [2.8141387730599545, 2.856880669284...
# 71   (Atom('K', [0.9335168940061267, 4.416902515844...
# 73   (Atom('Te', [1.216090619174645, 0.0, 1.9910788...
# 75   (Atom('Y', [1.7213457950097246, 1.721345795009...
# 80   (Atom('Ca', [0.0, 0.0, 0.0], magmom=0.0, index...
# 84   (Atom('O', [3.2663012459560563, 4.670023006340...
# 89   (Atom('Al', [0.0, 0.0, 0.0], magmom=0.0, index...
# 91   (Atom('V', [2.3669877637375145, 1.183493881868...
# 98   (Atom('B', [0.42147613696979347, 0.01189003291...
# 103  (Atom('Rh', [1.6779852027949917, 1.67798520279...
# 112  (Atom('Rh', [0.0, 0.0, 0.0], magmom=0.0, index...
# 129  (Atom('Mo', [-1.7785229511346756e-08, 2.053662...
# 142  (Atom('Li', [0.0, 0.0, 1.939138139532996], mag...
# 164  (Atom('As', [0.4744156806049671, 8.19657482755...
#
#                                       volume_vs_energy
# 6    [[55.04668560000001, 55.55637713333332, 56.066...
# 38   [[260.97630219613455, 263.3927494386915, 265.8...
# 47   [[26.086876651849693, 26.328421806033496, 26.5...
# 71   [[262.4747351325912, 264.9050567541896, 267.33...
# 73   [[91.8817734106883, 92.73253057189832, 93.5832...
# 75   [[35.6552522361, 35.98539346050831, 36.3155346...
# 80   [[39.18591704879998, 39.548749614066644, 39.91...
# 84   [[279.1800575681039, 281.765058101142, 284.350...
# 89   [[21.098491135199993, 21.2938475346, 21.489203...
# 91   [[95.99851790156245, 96.88739306731769, 97.776...
# 98   [[57.16602034446757, 57.69533534765705, 58.224...
# 103  [[33.293349331200005, 33.601621084266654, 33.9...
# 112  [[37.4738388264, 37.82081881553334, 38.1677988...
# 129  [[134.81012070308287, 136.05836256144468, 137....
# 142  [[121.62402757016993, 122.75017597359748, 123....
# 164  [[460.4564497527721, 464.71993539863087, 468.9...

# %%
bandgaps = combined_df.bandgap.values
bandgaps_qv = combined_df.bandgap_qv.values
bandgaps_direct_qv = combined_df.bandgap_direct_qv.values
bg_qv = [i if (i <= j) else j for i,j in zip(bandgaps_qv,bandgaps_direct_qv)]

# %%
fig = plt.figure(figsize=(9,6))
ax = plt.gca()
x = np.linspace(0.,12,1000)
sns.scatterplot(x=bandgaps,y=bg_qv)
ax.plot(x,x)
ax.set(xlabel='MatProj Bandgap [eV]',ylabel='QV Bandgap [eV]')
# Out:
# [Text(0, 0.5, 'QV Bandgap [eV]'), Text(0.5, 0, 'MatProj Bandgap [eV]')]

# %%
combined_df['mp_vol'] = combined_df.structure_final.apply(lambda x: x.get_volume())
combined_df['qv_vol'] = combined_df.system.apply(lambda x: x.get_volume())
combined_df.head()
# Out:
#      index                                  structure_initial  \
# 0     mp-1  (Atom('Cs', [0.0, 0.0, 0.0], magmom=0.0, index...
# 1  mp-1020  (Atom('Rh', [0.0, 1.93, 1.93], magmom=0.0, ind...
# 2  mp-1031  (Atom('Cd', [0.0, 0.0, 0.0], magmom=0.0, index...
# 3  mp-1033  (Atom('Be', [0.0, 0.0, 0.0], magmom=0.0, index...
# 4  mp-1053  (Atom('Zn', [1.8345, 1.8345, 1.8345], magmom=0...
#
#                                      structure_final  \
# 0  (Atom('Cs', [3.0266104319773843, -3.0806802534...
# 1  (Atom('Rh', [0.0, 1.95221343, 1.95221343], mag...
# 2  (Atom('Gd', [1.88608472, 1.88608472, 1.8860847...
# 3  (Atom('Be', [0.0, 0.0, 0.0], magmom=0.0, index...
# 4  (Atom('Zn', [1.843168155, 1.843168155, 1.84316...
#
#                        potcar  bandgap  bandgap_qv  bandgap_direct_qv  \
# 0               {'Cs': '_sv'}      0.0         0.0                0.0
# 1  {'Rh': '_pv', 'Ta': '_pv'}      0.0         0.0                0.0
# 2        {'Cd': '', 'Gd': ''}      0.0         0.0                0.0
# 3  {'Be': '_sv', 'Ni': '_pv'}      0.0         0.0                0.0
# 4      {'Zn': '', 'Nd': '_3'}      0.0         0.0                0.0
#
#        eos_errors                                           eos_fits  \
# 0            None  {'pouriertarantola': {'energy': -0.85932106780...
# 1            None  {'pouriertarantola': {'energy': -36.3172032132...
# 2  [antonschmidt]  {'pouriertarantola': {'energy': -11.8625369598...
# 3            None  {'pouriertarantola': {'energy': -10.4817534621...
# 4            None  {'p3': {'energy': -6.662929801545069, 'volume'...
#
#                                               system  \
# 0  (Atom('Cs', [0.0, 0.0, 0.0], magmom=0.0, index...
# 1  (Atom('Rh', [0.0, 1.952512548509679, 1.9525125...
# 2  (Atom('Cd', [0.0, 0.0, 0.0], magmom=0.0, index...
# 3  (Atom('Be', [0.0, 0.0, 0.0], magmom=0.0, index...
# 4  (Atom('Zn', [1.839922993738159, 1.839922993738...
#
#                                     volume_vs_energy      mp_vol      qv_vol
# 0  [[104.21489730785372, 105.17985006070417, 106....  114.041336  116.111876
# 1  [[51.761210399999975, 52.240480866666665, 52.7...   59.521227   59.548591
# 2  [[47.46093749999999, 47.90039062499997, 48.339...   53.675188   58.286923
# 3  [[16.279101562500003, 16.429833984374994, 16.5...   17.679898   17.848385
# 4  [[44.45142057810001, 44.863007805675, 45.27459...   50.093902   49.829775

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.gca()
x = np.linspace(0.,600,1000)
sns.scatterplot(x='qv_vol',y='mp_vol',data=combined_df,ax=ax)
ax.plot(x,x)
ax.set(xlabel='Quantum Valet Volume [cu. Ang]',ylabel='MatProj Volume [cu. Ang]')
# Out:
# [Text(0, 0.5, 'MatProj Volume [cu. Ang]'),
#  Text(0.5, 0, 'Quantum Valet Volume [cu. Ang]')]
